# %%
# %run "full_app_functions.ipynb"
# Out:
# C:\Users\vale2\anaconda3\Lib\site-packages\pydub\utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)
# WARNING:tensorflow:From C:\Users\vale2\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\vale2\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
input_path = 'AudioArchive/TestAudio/password_budapesthotel.wav'
splitted_dir = 'AudioArchive/TestSplitted'
waveletname = "mexh" 

# Detection, split e prediction
peak_detection_and_split(input_path, waveletname, splitted_dir)
predict(splitted_dir, "password_budapesthotel")
# Out:
# The wave is password_budapesthotel.wav using wavelet mexh
# Value of threshold: 0.0010522285010665655
# Number of peaks found: 13
#
# ...
# 1/1 [==============================] - 0s 48ms/step
# La password riconosciuta è: budapesthotel

# %%
input_path = 'AudioArchive/TestAudio/password_tesirusso2024_veloce.wav'
splitted_dir = 'AudioArchive/TestSplitted'
waveletname = "mexh" 

# Detection, split e prediction
peak_detection_and_split(input_path, waveletname, splitted_dir)
predict(splitted_dir, "password_tesirusso2024_veloce")
# Out:
# The wave is password_tesirusso2024_veloce.wav using wavelet mexh
# Value of threshold: 0.0010990563314408064
# Number of peaks found: 13
#
# ...
# 1/1 [==============================] - 0s 21ms/step
# La password riconosciuta è: mesirusso2024

# %%
input_path = 'AudioArchive/TestAudio/password_testnumero1.wav'
splitted_dir = 'AudioArchive/TestSplitted'
waveletname = "mexh" 

# Detection, split e prediction
peak_detection_and_split(input_path, waveletname, splitted_dir)
predict(splitted_dir, "password_testnumero1")
# Out:
# The wave is password_testnumero1.wav using wavelet mexh
# Value of threshold: 0.0011503553250804543
# Number of peaks found: 11
#
# ...
# 1/1 [==============================] - 0s 63ms/step
# La password riconosciuta è: tesrm7mero1
